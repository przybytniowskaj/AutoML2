# %%
from package_name.preprocessing import *
import numpy as np
import pandas as pd
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()

# %%
X = pd.DataFrame(data['data'], columns = ['mean radius', 'mean texture', 'mean perimeter', 'mean area',
        'mean smoothness', 'mean compactness', 'mean concavity',
        'mean concave points', 'mean symmetry', 'mean fractal dimension',
        'radius error', 'texture error', 'perimeter error', 'area error',
        'smoothness error', 'compactness error', 'concavity error',
        'concave points error', 'symmetry error',
        'fractal dimension error', 'worst radius', 'worst texture',
        'worst perimeter', 'worst area', 'worst smoothness',
        'worst compactness', 'worst concavity', 'worst concave points',
        'worst symmetry', 'worst fractal dimension'])
X.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
y = pd.DataFrame(data['target'])

# %%
# preprocessor = DataPreprocessor(num_strategy="mean", cat_strategy="most_frequent", test_size=0.4)
# X_train, y_train, X_test, y_test = preprocessor.fit_transform(X, y)

# %%
# from package_name.model_selection import *

# model_selector = ModelSelection(X_train, y_train, X_test, y_test)
# best_model, best_params, best_score = model_selector.compare_models()

# %%
from package_name.wrapper import PackageName

pipeline = PackageName(preprocess=True)
best_model, best_params, res = pipeline.fit(X, y)

res
# Out:
# Optimizing model: LogisticRegression
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'C': 1.6647293047370444, 'l1_ratio': 0.06689680094455495, 'class_weight': 'balanced', 'max_iter': 1500, 'solver': 'lbfgs'}, score: 0.9825
#
# Optimizing model: RandomForestClassifier
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'n_estimators': 732, 'criterion': 'log_loss', 'bootstrap': True, 'max_samples': 0.8915594462899888, 'max_features': 0.8997421063481311, 'min_samples_leaf': 0.05206623060646382}, score: 0.9561
#
# Optimizing model: SVC
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'C': 1.6537068998684064, 'kernel': 'linear', 'gamma': 0.1726338758438285, 'class_weight': 'balanced'}, score: 0.9825
#
# Optimizing model: XGBClassifier
#   0%|          | 0/50 [00:00<?, ?it/s]
# ...
